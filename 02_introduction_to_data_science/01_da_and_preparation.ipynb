# %% [markdown]
# # Data Warehouse
#
# **Definíció:**
# A Data Warehouse a vállalat teljes adatvagyonát integrált formában tartalmazó,
# **elemzésre és riportolásra optimalizált** adattárház.
#
# **Fő jellemzők:**
# - A teljes vállalat adatait tartalmazza
# - Strukturált adatok
#   - Relációs jellegű adatok
#   - Előre definiált séma
#   - Tipikus modellek: **csillag** és **hópehely séma**
# - Több üzleti terület (pl. értékesítés, pénzügy, marketing) adatait integrálja
# - Nagy mennyiségű, historikus adatok
# - Riportolásra és vizualizációra optimalizált
# - Összetett **ETL / ELT** folyamatok
#
# ---
#
# # Data Mart
#
# **Definíció:**
# A Data Mart a Data Warehouse egy részhalmaza, amely egy adott üzleti terület igényeire fókuszál.
#
# **Fő jellemzők:**
# - Egy konkrét üzleti területet szolgál ki
# - Kevesebb adat
# - Egyszerűbb, átláthatóbb struktúra
#   - Gyakran konkrét üzleti kérdésekre optimalizált
#   - Alapvetően ugyanazokat a sémákat használja, mint a Data Warehouse
# - Operatívabb, gyorsabb elemzésekre is alkalmas
#
# ---
#
# # Data Lake
#
# **Definíció:**
# A Data Lake egy központi, nyers adattároló, amelyben az adatok eredeti formájukban kerülnek eltárolásra.
#
# **Adattípusok:**
# - Strukturált: SQL táblák, CSV
# - Félstrukturált: JSON, XML
# - Strukturálatlan: képek, videók, logok
#
# **Felhasználás:**
# - Data Science
# - Machine Learning
# - Felfedező elemzések
#
# ---
#
# # Big Data
#
# **Definíció:**
# Olyan nagy mennyiségű, gyorsan keletkező és változatos adatok összessége,
# amelyek kezelése hagyományos eszközökkel nem hatékony, ezért
# **elosztott és párhuzamos feldolgozást igényel**.
#
# **Technológiai jellemzők:**
# - Elosztott tárolás
#   - Objektumtárolók (felhő)
#   - Példák: AWS S3, Azure Data Lake / Blob Storage, Google Cloud Storage
# - Párhuzamos feldolgozás
#   - Példa: Apache Spark
#
# **Big Data ismérvek (6V):**
# - **Value** – üzleti érték
# - **Volume** – nagy adatmennyiség
# - **Velocity** – gyors adatkeletkezés
# - **Variety** – változatos adattípusok
# - **Veracity** – adatminőség bizonytalansága
# - **Variability** – üzleti jelentés változása
#
# ---
#
# # Mesterséges Intelligencia
#
# ## Artificial Intelligence (AI)
#
# **Definíció:**
# Az AI olyan rendszerek összessége, amelyek emberi intelligenciát utánzó feladatokat végeznek.
#
# **Jellemzők:**
# - Gyűjtőfogalom
# - Nem egy konkrét algoritmus
#
# **Példák:**
# - Chatbotok
# - Arcfelismerés
#
# ---
#
# ## Machine Learning (ML)
#
# **Definíció:**
# Az AI egy részterülete, ahol a rendszer adatokból tanul,
# nem előre programozott szabályok alapján működik.
#
# **Lényege:**
# - Van tanító adat
# - A modell mintázatokat tanul
# - Képes előrejelzést vagy döntést hozni
#
# **Példák:**
# - Hitelbírálat
# - Termékajánló rendszerek
#
# ---
#
# ## Deep Learning
#
# **Definíció:**
# A Machine Learning speciális ága, amely többrétegű neurális hálókat használ.
#
# **Jellemzők:**
# - Nagy mennyiségű adat szükséges
# - Jelentős számítási kapacitás (GPU)
#
# **Példák:**
# - Képfelismerés
# - Önjáró járművek
# - ChatGPT-szerű modellek
#
# ---
#
# ## Neurális hálók – Alapok
#
# A mesterséges neuron a biológiai neuron által inspirált,
# **egyszerűsített matematikai modell**.
#
# **Felépítése:**
# - Bemenetek: \( x_1, \dots, x_n \) súlyokkal: \( w_1, \dots, w_n \)
# - Bias: \( x_0, w_0 \)
# - Súlyozott összeg + nemlineáris aktivációs függvény
# - Kimenet: \( y \)
# - Egyes hálótípusoknál lokális memória (visszacsatolás, késleltetés)
#
# ---
#
# # Üzleti elemzés lépései (CRISP-DM)
#
# **CRISP-DM:** Cross Industry Standard Process for Data Mining
#
# ## 1. Üzleti célok megértése
# - Probléma definiálása
# - Erőforrások feltérképezése
# - Döntéshozók azonosítása
# - Hipotézisek megfogalmazása
# - Potenciális adatforrások
#
# ## 2. Adatok megismerése
# - Adatgyűjtés (ETL)
# - Alapstatisztikák
# - Adatvizualizáció
# - Adatminőség vizsgálata
#
# ## 3. Adatok előkészítése
# - Adatkiválasztás
# - Adattisztítás
# - Változótranszformáció
# - Új változók létrehozása
# - Adatintegráció
#
# ## 4. Modellezés
# - Változók kiválasztása
# - Modell / algoritmus kiválasztása
# - Modell tanítása
#
# ## 5. Értékelés
# - Teljesítménymérés
# - Validáció
# - Üzleti célokkal való összevetés
# - Következtetések levonása
#
# ## 6. Implementáció
# - Modell élesítése
# - Üzembe helyezés
# - Folyamatos frissítés és monitorozás
#
# ---
#
# # Machine Learning – Tanulási típusok
#
# A gépi tanulási módszerek fő csoportjai:
# - **Felügyelt tanulás** – regresszió, klasszifikáció
# - **Felügyelet nélküli tanulás** – klaszterezés, dimenziócsökkentés
# - **Félig felügyelt tanulás**
# - **Megerősítéses tanulás**
#
# ## Alapváltozók típusai:
#
# ### Magyarázóváltozó (független változó)
# - Olyan változó, amely hatással van egy másik változóra.
# - Ezzel próbáljuk magyarázni vagy előre jelezni a célváltozó értékét.
# - A modell „bemenete”.
#
# Példák:
# - Tanulással töltött órák száma → magyarázóváltozó
# - Hőmérséklet → magyarázóváltozó
# - Reklámra költött összeg → magyarázóváltozó
#
# Jelölése gyakran: X
#
# ### Célváltozó (függő változó)
# Olyan változó, amelynek az értéke a magyarázóváltozóktól függ.
# - Amit meg akarunk magyarázni, megérteni vagy előre jelezni.
# - A modell „kimenete”.
#
# Példák:
# - Vizsgaeredmény → célváltozó
# - Fagylalteladás mennyisége → célváltozó
# - Bevétel → célváltozó
#
# Jelölése gyakran: Y
#
# ## Regresszió
# Regresszió = olyan modellezési feladat, ahol
# - a célváltozó folytonos szám,
# - és ezt magyarázó változók alapján becsüljük.
#
# A regressziós modell megtanul egy összefüggést:
# Y = f(X1,X2,…,Xp)+hiba
# Majd ezt használja ismeretlen esetekre.
#
# Tehát a regresszió lényege:
# - Van egy tanító adathalmaz
#   - ismerem a tulajdonságokat (magyarázóváltozók)
#   - ismerem a keresett mennyiséget (célváltozó),
# - Van egy új megfigyelés
#   - ismerem a tulajdonságokat
#   - nem ismerem a célváltozót
#   - a modell megbecsüli azt.
#
# 1. Metrikák (hibamérés / illeszkedés)
# - Hibamértékek
#   - MSE (Mean Squared Error): Négyzetes átlaghiba, erősen bünteti a nagy eltéréseket.
#   - RMSE (Root Mean Squared Error): MSE gyöke, azonos mértékegységű, mint a célváltozó.
#   - MAE (Mean Absolute Error): Átlagos abszolút hiba, robusztusabb outlierekre.
#   - MAPE (Mean Absolute Percentage Error): Relatív (százalékos) hiba, 0 környékén instabil.
#
# - Illeszkedési mutató
#   - R² (determinációs együttható): A magyarázott variancia aránya, lehet negatív is.
#
# 2. Veszteségfüggvény (tanításkor)
# - MSE
# - MAE
# - Huber loss
#
# 3. Validációs módok:
# - Train / test split
# - Cross-validation (k-fold)
# - Out-of-sample mérés
# - Idősor esetén: időalapú split
#
# ## Klasszifikáció
# pl. Churn modell
#
# Klasszifikáció = olyan modellezési feladat, ahol
# - a célváltozó kategória / osztály,
# - és a modell osztályba sorol.
#
# A klasszifikációs modell megtanulja:
#
# 𝑌 ∈ {A, B, C}
#
# Egy új megfigyeléshez megmondja, melyik osztályba tartozik.
#
# 1. Alap: konfúziós mátrix, ami megmutatja a modell hogyan döntött, és mi volt valójában igaz.
# - TP (True Positive), FP (False Positive),
# - FN (False Negative), TN (True Negative)
#
# 2. Metrikák:
# - Küszöbfüggő:
#   - Accuracy: Helyes osztályozások aránya (kiegyensúlyozott adatoknál jó).
#   - Precision: Pozitív előrejelzések pontossága.
#   - Recall (Sensitivity): Valódi pozitívak felismerési aránya.
#   - Specificity: Valódi negatívak felismerése.
#   - F1-score: Precision és Recall harmonikus átlaga.
#
# - Küszöbfüggetlen:
#   - ROC-AUC: Rangsorolási képesség
#   - PR-AUC: Ritka pozitív osztály esetén előnyös.
#
# 3. Veszteségfüggvény (tanításkor)
# - Log-loss / Cross-entropy
# - Hinge loss (SVM)
#
# 4. Validációs módok
# - Train / test split
# - Cross-validation
# - Stratified split (osztályarány megtartása)
# - Out-of-sample mérés
#
# ## Tanító- és tesztállományok szerepe a kiértékelésben
#
# Az egyes adatforrásokat integráljuk egy modellezési táblába, majd a modellezés megkezdése előtt az adatokat tanító- és tesztállományra bontjuk. A modell illesztését (tanítását) a tanítóállományon végezzük, míg a tesztállományt kizárólag a modell teljesítményének kiértékelésére használjuk.
#
# A tanító- és tesztállomány szétválasztására azért van szükség, hogy fel tudjuk mérni a modell általánosító képességét, és azonosítani tudjuk a túltanulás (overfitting) jelenségét. Overfitting esetén a modell nemcsak a valós összefüggéseket, hanem a tanító adatok véletlen zaját is megtanulja, ami gyenge teljesítményhez vezet új adatokon.
#
# A túltanulás mértékét a tesztállományon mért teljesítmény alapján, a modellverziók iteratív összehasonlításával tudjuk azonosítani.
#
# 1:59:36-tól folytatni
